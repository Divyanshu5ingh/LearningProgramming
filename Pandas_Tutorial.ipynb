# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshu5ingh/LearningProgramming/blob/main/Pandas_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=country).T

# %% [markdown]
# Read

# %%
df1=pd.read_csv('pokemon.csv')
df1
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
df1.shape
# Out:
# (801, 41)

# %%
df1.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
df1.dtypes
# Out:
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# base_total             int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# height_m             float64
# hp                     int64
# japanese_name         object
# name                  object
# percentage_male      float64
# ...

# %%
df1['against_bug'].dtypes
# Out:
# dtype('float64')

# %%
df1.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df1.tail()
# Out:
#            abilities  against_bug  against_dark  against_dragon  \
# 796  ['Beast Boost']         0.25           1.0             0.5
# 797  ['Beast Boost']         1.00           1.0             0.5
# 798  ['Beast Boost']         2.00           0.5             2.0
# 799  ['Prism Armor']         2.00           2.0             1.0
# 800   ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 796             0.5            1.0  ...              NaN             797
# ...

# %%
df1.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
df1[['type1','type2']]
# Out:
#        type1   type2
# 0      grass  poison
# 1      grass  poison
# 2      grass  poison
# 3       fire     NaN
# 4       fire     NaN
# ..       ...     ...
# 796    steel  flying
# 797    grass   steel
# 798     dark  dragon
# 799  psychic     NaN
# 800    steel   fairy
#
# [801 rows x 2 columns]

# %%
pd.set_option

# %%
df1.iloc[2]
# Out:
# abilities            ['Overgrow', 'Chlorophyll']
# against_bug                                  1.0
# against_dark                                 1.0
# against_dragon                               1.0
# against_electric                             0.5
# against_fairy                                0.5
# against_fight                                0.5
# against_fire                                 2.0
# against_flying                               2.0
# against_ghost                                1.0
# against_grass                               0.25
# against_ground                               1.0
# against_ice                                  2.0
# against_normal                               1.0
# against_poison                               1.0
# against_psychic                              2.0
# against_rock                                 1.0
# against_steel                                1.0
# against_water                                0.5
# ...

# %%
df1[300:500]
# Out:
#                                          abilities  against_bug  against_dark  \
# 300    ['Cute Charm', 'Normalize', 'Wonder Skin ']         1.00           1.0
# 301             ['Keen Eye', 'Stall', 'Prankster']         1.00           1.0
# 302  ['Hyper Cutter', 'Intimidate', 'Sheer Force']         0.25           0.5
# 303         ['Sturdy', 'Rock Head', 'Heavy Metal']         0.50           1.0
# 304         ['Sturdy', 'Rock Head', 'Heavy Metal']         0.50           1.0
# ..                                             ...          ...           ...
# 495                       ['Overgrow', 'Contrary']         2.00           1.0
# 496                       ['Overgrow', 'Contrary']         2.00           1.0
# 497                         ['Blaze', 'Thick Fat']         0.50           1.0
# 498                         ['Blaze', 'Thick Fat']         0.25           0.5
# 499                          ['Blaze', 'Reckless']         0.25           0.5
#
# ...

# %%
df1.iloc[1,4]
# Out:
# 0.5

# %%
df1.sort_values("type1")
# Out:
#                                   abilities  against_bug  against_dark  \
# 400               ['Shed Skin', 'Run Away']          1.0           1.0
# 283               ['Intimidate', 'Unnerve']          0.5           1.0
# 735                               ['Swarm']          1.0           1.0
# 736                             ['Battery']          1.0           1.0
# 737                            ['Levitate']          1.0           1.0
# ..                                      ...          ...           ...
# 393                  ['Torrent', 'Defiant']          1.0           1.0
# 394                  ['Torrent', 'Defiant']          0.5           1.0
# 159              ['Torrent', 'Sheer Force']          1.0           1.0
# 59   ['Water Absorb', 'Damp', 'Swift Swim']          1.0           1.0
# 381                             ['Drizzle']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# ...

# %%
df1.sort_values("pokedex_number", ascending = False)
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 800               ['Soul-Heart']         0.25           0.5             0.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 798              ['Beast Boost']         2.00           0.5             2.0
# 797              ['Beast Boost']         1.00           1.0             0.5
# 796              ['Beast Boost']         0.25           1.0             0.5
# ..                           ...          ...           ...             ...
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
#
# ...

# %%
df1.sort_values("pokedex_number") #by default ascending is true so it will sort data in ascending order
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
df1['total'] = df1.against_flying + df1.against_ghost
df1
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...
